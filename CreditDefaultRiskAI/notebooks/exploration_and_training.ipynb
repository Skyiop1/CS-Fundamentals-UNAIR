# %% [markdown]
# # Exploration and Training\n\nNotebook pendamping untuk Anti Kredit Macet AI. Pipeline utama berada di `src/train.py` agar training tidak dijalankan ulang dari `app.py`.

# %%
from src.data_loader import preprocess_raw_dataset, get_dataset_summary\n\ndf = preprocess_raw_dataset()\nget_dataset_summary(df)
